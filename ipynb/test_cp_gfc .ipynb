# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler

# %%
# cd ..

# %%
# %run -i test_cp_gfc.py
# Out:
# [facinv] 2023-11-03 13:15:03,067: -- The FACINV python package --
# [facinv] 2023-11-03 13:15:03,072:   LLLGZ, 2023 (c)
# [facinv] 2023-11-03 13:15:03,073: :solution      to ./out
# [facinv] 2023-11-03 13:15:03,073: :data          to ./data
# [facinv] 2023-11-03 13:15:03,074: :logs and tmps to ./tmp
# [facinv] 2023-11-03 13:15:03,490: generating the signature of this problem
# [facinv] 2023-11-03 13:15:03,490: {
#   "customer_num": 5,
#   "data_dir": "/Users/xue/github/facility-loc-inventory/data/data_0401_0inv.xlsx",
#   "one_period": false,
#   "plant_num": 2,
#   "sku_num": 2,
#   "warehouse_num": 13
# }
# [facinv] 2023-11-03 13:15:03,491: current data has not been generated before
# [facinv] 2023-11-03 13:15:03,491: creating a temporary cache @./out/data_0401_0inv-5-False-2-2-13.pk
# [facinv] 2023-11-03 13:15:40,202: dumping a temporary cache @./out/data_0401_0inv-5-False-2-2-13.pk
# setting T0003_T0021 to 300
# setting T0015_T0014 to 1100
# Cardinal Optimizer v6.5.1. Build date Apr 11 2023
# Copyright Cardinal Operations 2023. All Rights Reserved
#
# Fixed select_edge 0 Edge_P0001-GZA1_T0015_(P0001-GZA1, T0015)
# Fixed select_edge 0 Edge_P0001-GZA2_T0015_(P0001-GZA2, T0015)
# Fixed select_edge 1 Edge_P0001-GZA1_T0015_(P0001-GZA1, T0015)
# Fixed select_edge 1 Edge_P0001-GZA2_T0015_(P0001-GZA2, T0015)
# Fixed select_edge 2 Edge_P0001-GZA1_T0015_(P0001-GZA1, T0015)
# Fixed select_edge 2 Edge_P0001-GZA2_T0015_(P0001-GZA2, T0015)
# Fixed select_edge 3 Edge_P0001-GZA1_T0015_(P0001-GZA1, T0015)
# Fixed select_edge 3 Edge_P0001-GZA2_T0015_(P0001-GZA2, T0015)
# Fixed select_edge 4 Edge_P0001-GZA1_T0015_(P0001-GZA1, T0015)
# Fixed select_edge 4 Edge_P0001-GZA2_T0015_(P0001-GZA2, T0015)
# Fixed select_edge 5 Edge_P0001-GZA1_T0015_(P0001-GZA1, T0015)
# Fixed select_edge 5 Edge_P0001-GZA2_T0015_(P0001-GZA2, T0015)
# Fixed select_edge 6 Edge_P0001-GZA1_T0015_(P0001-GZA1, T0015)
# Fixed select_edge 6 Edge_P0001-GZA2_T0015_(P0001-GZA2, T0015)
# Setting parameter 'Logging' to 1
# Setting parameter 'Threads' to 8
# Setting parameter 'TimeLimit' to 3600
# Writing problem to /Users/xue/github/facility-loc-inventory_奇怪版本/ipynb/mm.lp
# Model fingerprint: 8dbf25ea
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6299 rows, 3856 columns and 14895 non-zero elements
#     2070 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     935 rows, 1412 columns and 3819 non-zero elements
#     98 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.04s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.05s
#          0         1      --      11  8.274500e+05  4.687929e+08  99.8%  0.08s
# H        0         1      --      11  8.274500e+05  8.285387e+05  0.13%  0.09s
# H        0         1      --      11  8.274500e+05  8.278036e+05  0.04%  0.09s
#          0         1      --      10  8.274534e+05  8.278036e+05  0.04%  0.09s
#          0         1      --      10  8.274534e+05  8.278036e+05  0.04%  0.09s
#          0         1      --       9  8.275325e+05  8.278036e+05  0.03%  0.10s
#          0         1      --       9  8.275325e+05  8.278036e+05  0.03%  0.10s
#          0         1      --       7  8.276631e+05  8.278036e+05  0.02%  0.11s
#          0         1      --       7  8.276631e+05  8.278036e+05  0.02%  0.11s
#          0         1      --       9  8.277136e+05  8.278036e+05  0.01%  0.11s
#          0         1      --       9  8.277136e+05  8.278036e+05  0.01%  0.11s
#          0         1      --       5  8.277646e+05  8.278036e+05  0.00%  0.11s
#          1         1   108.0       5  8.277646e+05  8.278036e+05  0.00%  0.11s
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          1         1   108.0       5  8.277646e+05  8.278036e+05  0.00%  0.11s
#
# Best solution   : 827803.618810628
# Best bound      : 827764.570800483
# Best gap        : 0.0047%
# Solve time      : 0.12
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :
# relaxing (6, Edge_T0015_T0020_(T0015, T0020))
# relaxing (6, Edge_T0015_T0021_(T0015, T0021))
# relaxing (6, Edge_T0015_T0022_(T0015, T0022))
# relaxing (6, Edge_T0015_T0023_(T0015, T0023))
# relaxing (6, Edge_T0015_T0024_(T0015, T0024))
# relaxing (6, Edge_T0015_T0025_(T0015, T0025))
# relaxing (6, Edge_T0015_T0026_(T0015, T0026))
# relaxing (6, Edge_T0024_T0019_(T0024, T0019))
# relaxing (6, Edge_T0024_T0020_(T0024, T0020))
# relaxing (6, Edge_T0024_T0021_(T0024, T0021))
# relaxing (6, Edge_T0024_T0022_(T0024, T0022))
# relaxing (6, Edge_T0024_T0023_(T0024, T0023))
# relaxing (6, Edge_T0026_T0001_(T0026, T0001))
# relaxing (6, Edge_T0026_T0002_(T0026, T0002))
# relaxing (6, Edge_T0026_T0003_(T0026, T0003))
# relaxing (6, Edge_T0026_T0015_(T0026, T0015))
# relaxing (6, Edge_T0026_T0020_(T0026, T0020))
# relaxing (6, Edge_T0026_T0021_(T0026, T0021))
# relaxing (6, Edge_T0026_T0022_(T0026, T0022))
# relaxing (6, Edge_T0026_T0023_(T0026, T0023))
# relaxing (6, Edge_T0026_T0024_(T0026, T0024))
# relaxing (6, Edge_T0026_T0025_(T0026, T0025))
# Model fingerprint: d14308b6
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6299 rows, 3856 columns and 14895 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     935 rows, 1412 columns and 3819 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.04s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.04s
#          0         1      --       6  8.274500e+05  4.687929e+08  99.8%  0.08s
# H        0         1      --       6  8.274500e+05  8.274884e+05  0.00%  0.08s
#          1         1     0.0       6  8.274500e+05  8.274884e+05  0.00%  0.08s
#          1         1     0.0       6  8.274500e+05  8.274884e+05  0.00%  0.08s
#
# Best solution   : 827488.408841178
# Best bound      : 827450.044689715
# Best gap        : 0.0046%
# Solve time      : 0.08
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :            0            0
#   rows          :  3.41061e-13  3.41061e-13
#   integrality   :            0

# %%
from tqdm.notebook import tqdm as tqdm_notebook

import utils
from cp_gfc import *
model.model.setParam("Logging", 0)
# get the first solutions
# 重写了下get_solution及存储的表结构
df_edges = model.get_solution(f"sol_lp_{pick_instance}/")
if df_edges.empty:
    print("no solution")
else:
    print('----------Originial Solution----------')
    for _,row in df_edges.iterrows():
        if 0 < row['y'] <1:
            print(row["obj_start"], row["obj_end"], row["t"],row['y'])
    # print(df_edges['y'])
lpval = model.model.objval

# for t in range(arg.T):
#
if not query_fractional_inter_edges(df_edges).empty:
    n = 1
    for _, row in query_fractional_inter_edges(df_edges).iterrows():
        start, end, t = row["obj_start"], row["obj_end"], row["t"]
        print("------------------Fractional Inter Edge------------------")
        print(k, start, end, t)
        k = 0
        while k < 20:
            # break
            for e in utils.get_out_edges(network, end):
                if e.capacity > 1e6:
                    print("无上界约束的边", e)
                    e.capacity = 0.4e5

            N1 = [e for e in utils.get_out_edges(network, end) if e.capacity < 1e6]
            N2 = [e for e in utils.get_in_edges(network, end) if e.capacity < 1e6]
            x = model.variables["sku_flow"]
            y = model.variables["select_edge"]
            d = 0
            print('---------Seperation Start----------')
            cutv, lbdv, subsets = seperation_gcf(model, x, y, t, N1, N2, d, dump=False, verbose=False)
            print("lbd", lbdv)
            if cutv > 1e-2:
                # 修改点2
                print('---------Add Cut----------')
                expr, cut_value, lbd, bool_voilate = eval_cut_c3(x, y, t, d, *subsets, lbdv=lbdv)
                model.model.addConstr(expr <= 0)
                model.model.solve()
                df_edges = model.get_solution(f"sol_lp_{pick_instance}/")
            else:
                print("cannot find")
                # print(df_edges['y'])
                for _, row in df_edges.iterrows():
                    if 0 < row['y'] < 1:
                        print(row["obj_start"], row["obj_end"], row["t"], row['y'])
                break
            # 看这一步和上一步相比的提升效果 新增了看这一步和mip之间的效果
            print(f"""
            --- {k} ---
            {start, end, t}
            {model.model.objval - lpval}
            {model.model.objval - mipval}
                """)
            lpval = model.model.objval
            k += 1
        print('After adding cuts for {}th fractional inter edge, then we have:'.format(n))
        for _, row in df_edges.iterrows():
            if 0 < row['y'] < 1:
                print(row["obj_start"], row["obj_end"], row["t"], row['y'])
        n += 1
else:
    print("no fractional inter edges")
    print(df_edges['y'])
# Out:
# --- summary ---------------------------
# lp relaxation: 827488.4088411783,
# mip          : 827803.618810628,
#
#
# [facinv] 2023-11-03 13:15:40,673: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:15:40,690: saving finished
# ----------Originial Solution----------
# T0015 T0014 0 0.01107380010720026
# T0015 T0014 1 0.0031168398199036586
# T0015 T0014 3 0.002579700102906478
# T0015 T0014 4 0.022481060013128277
# T0015 T0014 6 0.008039711791724727
# ------------------Fractional Inter Edge------------------
# (6, Edge_T0026_T0025_(T0026, T0025)) T0015 T0014 0
# ---------Seperation Start----------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-07-05
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0xb006ce2f
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [1e-02, 1e-02]
#   QLMatrix range   [1e-02, 9e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   QRHS range       [9e+02, 9e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 78 rows and 22 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 158 columns, 424 nonzeros
# Variable types: 104 continuous, 54 integer (54 binary)
# Found heuristic solution: objective 33.4923446
# Found heuristic solution: objective 33.4979337
#
# Root relaxation: objective 6.635369e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 663536.938    0   42   33.49793 663536.938      -     -    0s
# H    0     0                     386.0743818 663536.938      -     -    0s
# H    0     0                     711.4666791 557409.186      -     -    0s
#      0     0 480972.806    0   34  711.46668 480972.806      -     -    0s
#      0     0 479861.956    0   35  711.46668 479861.956      -     -    0s
#      0     0 370676.203    0   34  711.46668 370676.203      -     -    0s
#      0     0 338413.670    0   34  711.46668 338413.670      -     -    0s
# H    0     0                     882.6738847 338413.670      -     -    0s
#      0     2 338413.670    0   34  882.67388 338413.670      -     -    0s
# H   12    16                     911.1250369 338413.670      -  31.5    0s
# H  913   517                     911.1262477 232276.088      -   6.1    0s
# H 1672   870                     921.8001236 178142.638      -   5.4    0s
# H 2177   892                     921.8334031 101873.792      -   6.9    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 3
#   Implied bound: 5
#   Projected implied bound: 2
#   Clique: 3
#   MIR: 26
#   Flow cover: 50
#   RLT: 44
#   Relax-and-lift: 19
#
# Explored 28482 nodes (198122 simplex iterations) in 1.20 seconds (0.96 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 921.833 921.8 911.126 ... 33.4923
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 9.218001235800e+02, best bound 9.218334031397e+02, gap 0.0036%
# lbd 1914.3955950600016
# ---------Add Cut----------
# Model fingerprint: 6ffcf186
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6300 rows, 3856 columns and 14901 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     937 rows, 1412 columns and 3825 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.04s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.04s
#          0         1      --       7  8.274547e+05  4.687929e+08  99.8%  0.07s
# H        0         1      --       7  8.274547e+05  8.274984e+05  0.01%  0.08s
#          1         1     0.0       7  8.274547e+05  8.274984e+05  0.01%  0.08s
#          1         1     0.0       7  8.274547e+05  8.274984e+05  0.01%  0.08s
#
# Best solution   : 827498.408841178
# Best bound      : 827454.745714545
# Best gap        : 0.0053%
# Solve time      : 0.08
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :            0            0
#   rows          :  3.41061e-13  3.41061e-13
#   integrality   :            0
# [facinv] 2023-11-03 13:15:42,035: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:15:42,050: saving finished
#
#             --- 0 ---
#             (T0015, T0014, 0)
#             10.0
#             -305.2099694496719
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0xa2510e47
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-02, 1e+00]
#   QLMatrix range   [2e-02, 9e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   QRHS range       [9e+02, 9e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 79 rows and 29 columns
# Presolve time: 0.01s
# Presolved: 183 rows, 167 columns, 450 nonzeros
# Variable types: 111 continuous, 56 integer (56 binary)
# Found heuristic solution: objective 32.9189140
# Found heuristic solution: objective 32.9302606
#
# Root relaxation: objective 6.635675e+05, 108 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 663567.451    0   43   32.93026 663567.451      -     -    0s
# H    0     0                     805.8567923 663567.451      -     -    0s
#      0     0 557439.698    0   38  805.85679 557439.698      -     -    0s
#      0     0 501807.040    0   38  805.85679 501807.040      -     -    0s
#      0     0 371118.855    0   30  805.85679 371118.855      -     -    0s
#      0     0 349364.200    0   31  805.85679 349364.200      -     -    0s
#      0     0 349364.200    0   32  805.85679 349364.200      -     -    0s
#      0     0 324019.709    0   46  805.85679 324019.709      -     -    0s
# H    0     0                     808.0051312 324019.709      -     -    0s
#      0     0 295886.168    0   44  808.00513 295886.168      -     -    0s
# H    0     0                     845.5331949 295886.168      -     -    0s
# H    0     0                     855.3941650 295886.168      -     -    0s
#      0     2 295886.168    0   44  855.39417 295886.168      -     -    0s
# H  180   147                     877.9371945 253179.458      -   5.9    0s
# H  195   147                     883.5504017 253179.458      -   5.9    0s
# H  263   173                     895.3724129 253179.458      -   6.2    0s
# H  286   173                     899.9621155 253179.458      -   6.0    0s
# *  460   260              22     899.9953950 240941.601      -   6.3    0s
# * 4971  1027              45     899.9963950 10904.6048  1112%   7.4    0s
#
# Cutting planes:
#   Gomory: 4
#   Implied bound: 1
#   Projected implied bound: 2
#   MIR: 23
#   Flow cover: 47
#   RLT: 43
#   Relax-and-lift: 13
#
# Explored 14557 nodes (108993 simplex iterations) in 1.08 seconds (0.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 899.996 899.995 899.962 ... 805.857
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 8.999621154644e+02, best bound 8.999963950335e+02, gap 0.0038%
# lbd 1914.3955950599993
# ---------Add Cut----------
# Model fingerprint: 73cc5bd2
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6301 rows, 3856 columns and 14908 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     938 rows, 1412 columns and 3832 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.04s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.04s
#          0         1      --       6  8.274547e+05  4.687929e+08  99.8%  0.07s
# H        0         1      --       6  8.274547e+05  8.274884e+05  0.00%  0.07s
#          1         1     0.0       6  8.274547e+05  8.274884e+05  0.00%  0.07s
#          1         1     0.0       6  8.274547e+05  8.274884e+05  0.00%  0.07s
#
# Best solution   : 827488.408841167
# Best bound      : 827454.745714486
# Best gap        : 0.0041%
# Solve time      : 0.07
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :  5.68434e-14  5.68434e-14
#   rows          :  3.41061e-13  3.41061e-13
#   integrality   :            0
# [facinv] 2023-11-03 13:15:43,256: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:15:43,271: saving finished
#
#             --- 1 ---
#             (T0015, T0014, 0)
#             -10.000000011292286
#             -315.2099694609642
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x08870af2
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [5e-01, 9e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   QRHS range       [9e+02, 9e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 172 rows, 159 columns, 419 nonzeros
# Variable types: 105 continuous, 54 integer (54 binary)
# Found heuristic solution: objective 9.2873729
# Found heuristic solution: objective 9.5359883
#
# Root relaxation: objective 6.635675e+05, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 663567.450    0   42    9.53599 663567.450      -     -    0s
# H    0     0                      17.2770294 663567.450      -     -    0s
#      0     0 557439.698    0   39   17.27703 557439.698      -     -    0s
#      0     0 539997.910    0   39   17.27703 539997.910      -     -    0s
#      0     0 371635.968    0   30   17.27703 371635.968      -     -    0s
#      0     0 349832.943    0   28   17.27703 349832.943      -     -    0s
#      0     0 349364.200    0   32   17.27703 349364.200      -     -    0s
#      0     0 349013.438    0   32   17.27703 349013.438      -     -    0s
#      0     0 325620.582    0   44   17.27703 325620.582      -     -    0s
#      0     0 305728.745    0   44   17.27703 305728.745      -     -    0s
#      0     2 305728.745    0   44   17.27703 305728.745      -     -    0s
# H  263   200                      31.8752704 269058.398      -   6.1    0s
# H 1451   693                      31.8762704 201692.238      -   5.2    0s
# H 1759   785                      31.8772704 201692.238      -   5.1    0s
# H15193  1926                      31.8773369 30246.2649      -   7.6    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 16
#   Implied bound: 8
#   Projected implied bound: 1
#   Clique: 5
#   MIR: 41
#   Flow cover: 80
#   GUB cover: 1
#   Inf proof: 1
#   RLT: 74
#   Relax-and-lift: 13
#
# Explored 71362 nodes (609566 simplex iterations) in 2.58 seconds (2.88 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 31.8773 31.8773 31.8763 ... 9.28737
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.187527036170e+01, best bound 3.187733692362e+01, gap 0.0065%
# lbd 62.81875506001916
# ---------Add Cut----------
# Model fingerprint: fa9b76c6
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6302 rows, 3856 columns and 14912 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     939 rows, 1412 columns and 3836 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.05s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.05s
#          0         1      --       7  8.274598e+05  4.687929e+08  99.8%  0.08s
# H        0         1      --       7  8.274598e+05  8.274984e+05  0.00%  0.08s
#          1         1     0.0       7  8.274598e+05  8.274984e+05  0.00%  0.08s
#          1         1     0.0       7  8.274598e+05  8.274984e+05  0.00%  0.08s
#
# Best solution   : 827498.408841173
# Best bound      : 827459.819879115
# Best gap        : 0.0047%
# Solve time      : 0.08
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :  5.68434e-14  5.68434e-14
#   rows          :  2.27374e-13  2.27374e-13
#   integrality   :            0
# [facinv] 2023-11-03 13:15:45,983: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:15:45,998: saving finished
#
#             --- 2 ---
#             (T0015, T0014, 0)
#             10.000000005587935
#             -305.20996945537627
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x0c806a07
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [4e-01, 1e+00]
#   QLMatrix range   [4e-01, 9e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   QRHS range       [9e+02, 9e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 83 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 199 rows, 174 columns, 492 nonzeros
# Variable types: 117 continuous, 57 integer (57 binary)
# Found heuristic solution: objective 15.8963757
# Found heuristic solution: objective 16.0786344
#
# Root relaxation: objective 6.635675e+05, 109 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 
0s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 1
#   Implied bound: 2
#   Clique: 2
#   MIR: 20
#   Flow cover: 55
#   RLT: 24
#   Relax-and-lift: 16
#
# Explored 29909 nodes (265189 simplex iterations) in 2.62 seconds (2.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 199.9 199.898 199.897 ... 14.5364
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.998973203675e+02, best bound 1.999004952578e+02, gap 0.0016%
# lbd 1914.39559506
# ---------Add Cut----------
# Model fingerprint: 537c99d4
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6304 rows, 3856 columns and 14927 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     941 rows, 1412 columns and 3851 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.04s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.05s
#          0         1      --       7  8.274598e+05  4.687929e+08  99.8%  0.08s
# H        0         1      --       7  8.274598e+05  8.274984e+05  0.00%  0.08s
#          1         1     0.0       7  8.274598e+05  8.274984e+05  0.00%  0.08s
#          1         1     0.0       7  8.274598e+05  8.274984e+05  0.00%  0.08s
#
# Best solution   : 827498.408841173
# Best bound      : 827459.819879115
# Best gap        : 0.0047%
# Solve time      : 0.08
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :  5.68434e-14  5.68434e-14
#   rows          :  2.27374e-13  2.27374e-13
#   integrality   :            0
# [facinv] 2023-11-03 13:15:51,301: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:15:51,316: saving finished
#
#             --- 4 ---
#             (T0015, T0014, 0)
#             -10.0
#             -305.20996945537627
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x5d58f49b
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [5e-01, 1e+00]
#   QLMatrix range   [5e-01, 9e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   QRHS range       [9e+02, 9e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 83 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 199 rows, 174 columns, 492 nonzeros
# Variable types: 117 continuous, 57 integer (57 binary)
# Found heuristic solution: objective 9.2873730
# Found heuristic solution: objective 9.5359883
#
# Root relaxation: objective 6.635675e+05, 109 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 663567.451    0   43    9.53599 663567.451      -     -    0s
#      0     0 557439.698    0   41    9.53599 557439.698      -     -    0s
#      0     0 539997.910    0   41    9.53599 539997.910      -     -    0s
#      0     0 371635.968    0   29    9.53599 371635.968      -     -    0s
#      0     0 349013.438    0   32    9.53599 349013.438      -     -    0s
#      0     0 319691.955    0   47    9.53599 319691.955      -     -    0s
#      0     0 298625.241    0   45    9.53599 298625.241      -     -    0s
#      0     2 298625.241    0   45    9.53599 298625.241      -     -    0s
# *  167   155              20       9.5369883 282276.033      -   5.6    0s
# *  205   167              21      17.2780294 282276.033      -   5.3    0s
# H 2391   898                      31.8752704 178139.988      -   5.8    0s
# H 3853  1275                      31.8762704 87838.9267      -   6.8    0s
# H 9066   812                      31.9097860 20974.6487      -   8.1    0s
# * 9705   884              43      32.4144384 20391.1751      -   8.1    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 41
#   Implied bound: 11
#   Projected implied bound: 2
#   Clique: 6
#   MIR: 28
#   Flow cover: 70
#   RLT: 69
#   Relax-and-lift: 22
#
# Explored 51258 nodes (531592 simplex iterations) in 2.40 seconds (2.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 32.4144 31.9098 31.8763 ... 9.28737
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.187520932859e+01, best bound 3.241443836890e+01, gap 1.6917%
# lbd 62.81887896409939
# ---------Add Cut----------
# Model fingerprint: f667ee06
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6305 rows, 3856 columns and 14932 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     942 rows, 1412 columns and 3856 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.04s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.04s
#          0         1      --       7  8.274598e+05  4.687929e+08  99.8%  0.08s
# H        0         1      --       7  8.274598e+05  8.274984e+05  0.00%  0.08s
#          1         1     0.0       7  8.274598e+05  8.274984e+05  0.00%  0.08s
#          1         1     0.0       7  8.274598e+05  8.274984e+05  0.00%  0.08s
#
# Best solution   : 827498.408841173
# Best bound      : 827459.819879115
# Best gap        : 0.0047%
# Solve time      : 0.08
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :  5.68434e-14  5.68434e-14
#   rows          :  2.27374e-13  2.27374e-13
#   integrality   :            0
# [facinv] 2023-11-03 13:15:53,847: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:15:53,863: saving finished
#
#             --- 5 ---
#             (T0015, T0014, 0)
#             0.0
#             -305.20996945537627
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x59111e83
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [5e-01, 1e+00]
#   QLMatrix range   [5e-01, 9e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   QRHS range       [9e+02, 9e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 79 rows and 29 columns
# Presolve time: 0.01s
# Presolved: 183 rows, 167 columns, 450 nonzeros
# Variable types: 111 continuous, 56 integer (56 binary)
# Found heuristic solution: objective 9.2873729
# Found heuristic solution: objective 9.5359883
#
# Root relaxation: objective 6.635675e+05, 109 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 663567.451    0   43    9.53599 663567.451      -     -    0s
# H    0     0                      17.2770294 663567.451      -     -    0s
#      0     0 557439.698    0   38   17.27703 557439.698      -     -    0s
#      0     0 539997.910    0   38   17.27703 539997.910      -     -    0s
#      0     0 371635.968    0   29   17.27703 371635.968      -     -    0s
#      0     0 349364.200    0   32   17.27703 349364.200      -     -    0s
#      0     0 349013.438    0   33   17.27703 349013.438      -     -    0s
#      0     0 321739.886    0   43   17.27703 321739.886      -     -    0s
#      0     0 294609.095    0   43   17.27703 294609.095      -     -    0s
#      0     2 294609.095    0   42   17.27703 294609.095      -     -    0s
# H  263   200                      31.8752704 247872.677      -   5.6    0s
# *  648   379              25      31.9085780 243538.970      -   5.4    0s
# H 2262   960                      31.9085780 180047.942      -   5.4    0s
# *28600  4246              42      31.9095780 13388.2275      -   7.3    1s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 38
#   Implied bound: 13
#   Clique: 10
#   MIR: 36
#   StrongCG: 1
#   Flow cover: 78
#   RLT: 86
#   Relax-and-lift: 11
#
# Explored 111372 nodes (923533 simplex iterations) in 4.56 seconds (3.81 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 31.9096 31.9086 31.9086 ... 9.28737
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.187527036171e+01, best bound 3.190957795466e+01, gap 0.1076%
# lbd 62.81875506
# ---------Add Cut----------
# Model fingerprint: 3b0df500
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6306 rows, 3856 columns and 14937 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     943 rows, 1412 columns and 3861 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.05s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.05s
#          0         1      --       7  8.274600e+05  4.687929e+08  99.8%  0.08s
# H        0         1      --       7  8.274600e+05  8.274900e+05  0.00%  0.08s
#          1         1     0.0       7  8.274600e+05  8.274900e+05  0.00%  0.08s
#          1         1     0.0       7  8.274600e+05  8.274900e+05  0.00%  0.08s
#
# Best solution   : 827490.024716774
# Best bound      : 827460.008479774
# Best gap        : 0.0036%
# Solve time      : 0.08
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :  7.81597e-14  7.81597e-14
#   rows          :  2.27374e-13  2.27374e-13
#   integrality   :            0
# [facinv] 2023-11-03 13:15:58,566: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:15:58,587: saving finished
#
#             --- 6 ---
#             (T0015, T0014, 0)
#             -8.384124398697168
#             -313.59409385407344
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0xfacf4a36
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [9e-01, 9e-01]
#   QLMatrix range   [9e-01, 9e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   QRHS range       [9e+02, 9e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 172 rows, 159 columns, 419 nonzeros
# Variable types: 105 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -9.0451454
# Found heuristic solution: objective -8.6124652
#
# Root relaxation: objective 6.635675e+05, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 
0s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 30
#   Implied bound: 8
#   Projected implied bound: 1
#   Clique: 12
#   MIR: 24
#   Flow cover: 73
#   RLT: 65
#   Relax-and-lift: 10
#   BQP: 1
#   PSD: 1
#
# Explored 124779 nodes (1024654 simplex iterations) in 3.72 seconds (3.89 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 30.9768 30.9768 30.9435 ... -38.9331
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.094348469829e+01, best bound 3.097676521817e+01, gap 0.1076%
# lbd 1851.5768399999997
# ---------Add Cut----------
# Model fingerprint: 89f29494
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6308 rows, 3856 columns and 14946 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     945 rows, 1412 columns and 3870 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.04s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.04s
#          0         1      --       7  8.274600e+05  4.687929e+08  99.8%  0.07s
# H        0         1      --       7  8.274600e+05  8.274997e+05  0.00%  0.09s
#          1         1     0.0       7  8.274600e+05  8.274997e+05  0.00%  0.09s
#          1         1     0.0       7  8.274600e+05  8.274997e+05  0.00%  0.09s
#
# Best solution   : 827499.730245144
# Best bound      : 827460.008479774
# Best gap        : 0.0048%
# Solve time      : 0.09
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :  1.16415e-10  1.16415e-10
#   rows          :  2.32831e-10  2.32831e-10
#   integrality   :            0
# [facinv] 2023-11-03 13:16:04,098: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:16:04,112: saving finished
#
#             --- 8 ---
#             (T0015, T0014, 0)
#             4.6566128730773926e-09
#             -303.8885654839687
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x5f66a0f6
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [5e-01, 9e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   QRHS range       [9e+02, 9e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -40.2540323
# Found heuristic solution: objective -25.3446816
#
# Root relaxation: objective 6.963555e+05, 111 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696355.514    0   43  -25.34468 696355.514      -     -    0s
# H    0     0                       0.0000000 696355.514      -     -    0s
# H    0     0                       0.0120000 696355.514      -     -    0s
#      0     0 597977.513    0   38    0.01200 597977.513      -     -    0s
#      0     0 564493.942    0   39    0.01200 564493.942      -     -    0s
#      0     0 396930.830    0   30    0.01200 396930.830      -     -    0s
#      0     0 372561.143    0   31    0.01200 372561.143      -     -    0s
#      0     0 372561.143    0   32    0.01200 372561.143      -     -    0s
#      0     0 346433.676    0   45    0.01200 346433.676      -     -    0s
#      0     0 321572.618    0   45    0.01200 321572.618      -     -    0s
#      0     2 321572.618    0   45    0.01200 321572.618      -     -    0s
# H  126   130                       0.0332345 273928.968      -   5.9    0s
# H  135   130                       0.2371426 273928.968      -   5.8    0s
# H 2953  1380                       0.5841780 166137.958      -   5.5    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 11
#   Implied bound: 9
#   Projected implied bound: 2
#   Clique: 8
#   MIR: 31
#   Flow cover: 65
#   RLT: 66
#   Relax-and-lift: 18
#
# Explored 116988 nodes (566567 simplex iterations) in 2.53 seconds (2.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 0.584178 0.0332345 0.012 ... -40.254
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective -0.000000000000e+00, best bound 5.841779570546e-01, gap -
# lbd 20285.33903823654
# cannot find
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.00311683981990366
# T0015 T0014 2 1.3670841299428182e-15
# T0015 T0014 3 0.002579700102906478
# T0015 T0014 4 0.022481060013128277
# T0015 T0014 6 0.008039711791724727
# T0015 T0024 4 0.9999999999999974
# After adding cuts for 1th fractional inter edge, then we have:
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.00311683981990366
# T0015 T0014 2 1.3670841299428182e-15
# T0015 T0014 3 0.002579700102906478
# T0015 T0014 4 0.022481060013128277
# T0015 T0014 6 0.008039711791724727
# T0015 T0024 4 0.9999999999999974
# ------------------Fractional Inter Edge------------------
# 9 T0015 T0014 1
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x81ef5e78
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [3e-03, 3e-03]
#   QLMatrix range   [3e-03, 3e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 3e+02]
#   QRHS range       [3e+02, 3e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 80 rows and 21 columns
# Presolve time: 0.01s
# Presolved: 145 rows, 155 columns, 392 nonzeros
# Variable types: 101 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -0.0000000
#
# Root relaxation: objective 7.268895e+05, 122 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 726889.483    0   50   -0.00000 726889.483      -     -    0s
# ...
#   Projected implied bound: 1
#   Clique: 1
#   MIR: 21
#   Flow cover: 49
#   GUB cover: 1
#   RLT: 34
#   Relax-and-lift: 24
#
# Explored 30978 nodes (192583 simplex iterations) in 2.64 seconds (2.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 25.1587 15.7361 15.4335 ... 3.91182
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.515768606757e+01, best bound 2.515868606755e+01, gap 0.0040%
# lbd 62.818755060000015
# ---------Add Cut----------
# Model fingerprint: 5e435a2f
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6336 rows, 3856 columns and 15163 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     960 rows, 1412 columns and 3952 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.04s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.04s
#          0         1      --      10  8.274819e+05  4.687929e+08  99.8%  0.08s
# H        0         1      --      10  8.274819e+05  8.275266e+05  0.01%  0.09s
#          1         1     0.0      10  8.274819e+05  8.275266e+05  0.01%  0.09s
#          1         1     0.0      10  8.274819e+05  8.275266e+05  0.01%  0.09s
#
# Best solution   : 827526.648126963
# Best bound      : 827481.933682561
# Best gap        : 0.0054%
# Solve time      : 0.09
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :  1.16415e-10  1.16415e-10
#   rows          :  5.82077e-10  5.82077e-10
#   integrality   :            0
# [facinv] 2023-11-03 13:20:42,725: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:20:42,739: saving finished
#
#             --- 3 ---
#             (T0015, T0014, 6)
#             -4.403522151289508
#             -276.97068366524763
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x514721cf
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [6e-01, 6e-01]
#   QLMatrix range   [6e-01, 7e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 7e+02]
#   QRHS range       [7e+02, 7e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 172 rows, 159 columns, 419 nonzeros
# Variable types: 105 continuous, 54 integer (54 binary)
# Found heuristic solution: objective 2.7621366
# Found heuristic solution: objective 3.0762676
#
# Root relaxation: objective 6.634392e+05, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 663439.165    0   42    3.07627 663439.165      -     -    0s
# H    0     0                      12.8572432 663439.165      -     -    0s
#      0     0 563613.279    0   38   12.85724 563613.279      -     -    0s
#      0     0 533769.325    0   39   12.85724 533769.325      -     -    0s
#      0     0 372037.126    0   30   12.85724 372037.126      -     -    0s
#      0     0 349817.512    0   28   12.85724 349817.512      -     -    0s
#      0     0 349414.596    0   32   12.85724 349414.596      -     -    0s
#      0     0 349414.596    0   32   12.85724 349414.596      -     -    0s
#      0     0 325370.188    0   45   12.85724 325370.188      -     -    0s
#      0     0 300002.371    0   43   12.85724 300002.371      -     -    0s
#      0     2 300002.371    0   43   12.85724 300002.371      -     -    0s
# H  523   376                      12.8572432 260558.309      -   6.1    0s
# * 1293   824              22      12.8582432 199398.958      -   5.9    0s
# H 4149  1395                      12.8592432 65779.7624      -   6.5    0s
# * 5279  1149              51      12.8592432 46813.3763      -   7.1    0s
# H38522  2018                      12.8592436 1212.21919  9327%   8.2    1s
# H39587  1995                      12.8592442 1072.89667  8243%   8.2    1s
# H39606  1995                      12.8592445 1072.89667  8243%   8.2    1s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 31
#   Implied bound: 17
#   Projected implied bound: 1
#   Clique: 13
#   MIR: 47
#   Flow cover: 98
#   Inf proof: 1
#   RLT: 72
#   Relax-and-lift: 7
#   PSD: 2
#
# Explored 51031 nodes (422316 simplex iterations) in 2.08 seconds (2.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 12.8592 12.8592 12.8592 ... 2.76214
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.285724300166e+01, best bound 1.285924446401e+01, gap 0.0156%
# lbd 34.04901302520464
# ---------Add Cut----------
# Model fingerprint: 3b79e805
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6337 rows, 3856 columns and 15166 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     961 rows, 1412 columns and 3955 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.05s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.05s
#          0         1      --      11  8.274849e+05  4.687929e+08  99.8%  0.08s
# H        0         1      --      11  8.274849e+05  8.275353e+05  0.01%  0.10s
# H        0         1      --      11  8.274849e+05  8.275287e+05  0.01%  0.10s
#          1         1     0.0      11  8.274849e+05  8.275287e+05  0.01%  0.10s
#          1         1     0.0      11  8.274849e+05  8.275287e+05  0.01%  0.10s
#
# Best solution   : 827528.747569339
# Best bound      : 827484.857032537
# Best gap        : 0.0053%
# Solve time      : 0.10
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :  1.16415e-10  1.16415e-10
#   rows          :  1.16415e-10  1.16415e-10
#   integrality   :            0
# [facinv] 2023-11-03 13:20:44,969: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:20:44,985: saving finished
#
#             --- 4 ---
#             (T0015, T0014, 6)
#             2.0994423761731014
#             -274.87124128907453
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0xd3b18fa7
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [6e-01, 1e+00]
#   QLMatrix range   [6e-01, 7e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 7e+02]
#   QRHS range       [7e+02, 7e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 79 rows and 29 columns
# Presolve time: 0.01s
# Presolved: 183 rows, 167 columns, 450 nonzeros
# Variable types: 111 continuous, 56 integer (56 binary)
# Found heuristic solution: objective 5.1648020
# Found heuristic solution: objective 5.4548094
#
# Root relaxation: objective 6.634392e+05, 109 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 663439.165    0   43    5.45481 663439.165      -     -    0s
#      0     0 563625.878    0   38    5.45481 563625.878      -     -    0s
#      0     0 548816.426    0   38    5.45481 548816.426      -     -    0s
#      0     0 373254.133    0   28    5.45481 373254.133      -     -    0s
#      0     0 349815.559    0   34    5.45481 349815.559      -     -    0s
#      0     0 349362.020    0   35    5.45481 349362.020      -     -    0s
#      0     0 319865.013    0   48    5.45481 319865.013      -     -    0s
#      0     0 300003.419    0   43    5.45481 300003.419      -     -    0s
# H    0     0                       5.4548094 300003.419      -     -    0s
#      0     2 300003.419    0   43    5.45481 300003.419      -     -    0s
# H  263   239                      14.4846582 243066.905      -   5.5    1s
# *  498   338              22      14.5179662 237411.550      -   5.2    1s
# * 4493  1377              45      14.5514824 58176.4171      -   6.1    1s
# * 8815   946              43      14.5524824 16061.0356      -   7.6    2s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 24
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 13
#   MIR: 33
#   StrongCG: 1
#   Flow cover: 81
#   GUB cover: 1
#   RLT: 62
#   Relax-and-lift: 8
#   BQP: 4
#   PSD: 2
#
# Explored 30754 nodes (288319 simplex iterations) in 3.29 seconds (1.57 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 14.5525 14.5515 14.518 ... 5.1648
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.448465816973e+01, best bound 1.455248236041e+01, gap 0.4682%
# lbd 34.0490125
# ---------Add Cut----------
# Model fingerprint: 2b066af3
#
# Using Cardinal Optimizer v6.5.1 on macOS (aarch64)
# Hardware has 8 cores and 8 threads. Using instruction set ARMV8 (30)
# Minimizing a MIP problem
#
# The original problem has:
#     6338 rows, 3856 columns and 15171 non-zero elements
#     1594 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     962 rows, 1412 columns and 3960 non-zero elements
#     91 binaries
#
# Starting the MIP solver with 8 threads and 32 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0 -1.869609e+09            --    Inf  0.05s
# H        0         1      --       0 -1.869609e+09  4.687929e+08 125.1%  0.05s
#          0         1      --      11  8.274849e+05  4.687929e+08  99.8%  0.09s
# H        0         1      --      11  8.274849e+05  8.275353e+05  0.01%  0.11s
# H        0         1      --      11  8.274849e+05  8.275337e+05  0.01%  0.12s
#          1         1     0.0      11  8.274849e+05  8.275337e+05  0.01%  0.12s
#          1         1     0.0      11  8.274849e+05  8.275337e+05  0.01%  0.12s
#
# Best solution   : 827533.694457042
# Best bound      : 827484.857032537
# Best gap        : 0.0059%
# Solve time      : 0.12
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :  1.16415e-10  1.16415e-10
#   rows          :  1.16415e-10  1.16415e-10
#   integrality   :            0
# [facinv] 2023-11-03 13:20:48,471: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:20:48,511: saving finished
#
#             --- 5 ---
#             (T0015, T0014, 6)
#             4.946887703379616
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0xbc9c5c54
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [6e-01, 6e-01]
#   QLMatrix range   [6e-01, 7e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 7e+02]
#   QRHS range       [7e+02, 7e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -49.1928797
# Found heuristic solution: objective -30.9727449
#
# Root relaxation: objective 6.962272e+05, 111 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696227.228    0   43  -30.97274 696227.228      -     -    0s
# H    0     0                       0.0000000 696227.228      -     -    0s
# H    0     0                       0.0060000 696227.228      -     -    0s
#      0     0 596764.133    0   37    0.00600 596764.133      -     -    0s
#      0     0 563200.857    0   38    0.00600 563200.857      -     -    0s
#      0     0 396975.759    0   30    0.00600 396975.759      -     -    0s
#      0     0 371731.464    0   32    0.00600 371731.464      -     -    0s
#      0     0 371502.972    0   32    0.00600 371502.972      -     -    0s
#      0     0 345273.607    0   48    0.00600 345273.607      -     -    0s
#      0     0 322081.158    0   48    0.00600 322081.158      -     -    0s
#      0     2 322081.158    0   48    0.00600 322081.158      -     -    0s
# *  139   131              19       0.0327257 285391.882      -   6.3    0s
# H  175   168                       0.0631100 285391.882      -   5.7    0s
# *29121  7609              39       0.3166495 13756.6130      -   5.6    2s
# *29168  7226              43       0.3874224 13756.6130      -   5.7    2s
# *29174  6859              43       0.4032348 13756.6130      -   5.7    2s
# *29207  6501              47       0.4141472 5051.12937      -   5.7    2s
# *29276  6146              47       0.4142544 1764.31227      -   5.7    2s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Implied bound: 6
#   Projected implied bound: 1
#   Clique: 8
#   MIR: 12
#   Flow cover: 35
#   RLT: 31
#   Relax-and-lift: 9
#
# Explored 29427 nodes (167107 simplex iterations) in 2.27 seconds (1.45 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.414254 0.414147 0.403235 ... -30.9727
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective -0.000000000000e+00, best bound 4.142543539674e-01, gap -
# lbd 3341.433418413997
# cannot find
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 1 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0003 4 0.9999999999999996
# T0015 T0003 5 0.9999999999999996
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998
# After adding cuts for 4th fractional inter edge, then we have:
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 1 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0003 4 0.9999999999999996
# T0015 T0003 5 0.9999999999999996
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998

# %% [markdown]
# Then we see that
#
# - CG and LP are different
# - but they are worse than MIP (as expected)

# %%
lpval = model.model.objval
# 注意这里面的cg是没考虑edge的lowerbound的（无论是在pricing里面还是在RMP里面）
# 解更大可能是因为松弛后有的是0.3 正常来讲就是0了 但是现在额外加了新的约束 导致搜索空间变小 所以目标函数变大
print(
    f"""
--- summary ---------------------------
lp relaxation: {lpval},
mip          : {mipval},
cg           : {np_cg.RMP_model.objval}
"""
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       1 lpval = model.model.objval
#       2 # 注意这里面的cg是没考虑edge的lowerbound的（无论是在pricing里面还是在RMP里面）
#       3 # 解更大可能是因为松弛后有的是0.3 正常来讲就是0了 但是现在额外加了新的约束 导致搜索空间变小 所以目标函数变大
#       4 print(
#       5     f"""
#       6 --- summary ---------------------------
#       7 lp relaxation: {lpval},
#       8 mip          : {mipval},
# ----> 9 cg           : {np_cg.RMP_model.objval}
#      10 """
#      11 )
#
# NameError: name 'np_cg' is not defined

# %% [markdown]
# ## GFC in `partial LP relaxation`
# Our goal is to cutoff these solutions

# %%
from tqdm.notebook import tqdm as tqdm_notebook

import utils
from cp_gfc import *

# %% [markdown]
# # 反了吧 应该流入是N1 流出是N2吧
# - Let `inbound edges` as $N_2$, `out` as $N_1$,
# - net inventory as $d$,
# we see,
#
# \begin{align*}
# \begin{aligned}
# & \sum_{j \in N_1} x_j-\sum_{j \in N_2} x_j \leq d, \\
# & l_j y_j \leq x_j \leq u_j y_j, \quad y_j \in\{0,1\}, \quad j \in N_1 \cup N_2
# \end{aligned}
# \end{align*}
#
# where each $x_j$ is the total flow summarizing all SKUs

# %%
model.model.setParam("Logging", 0)
# get the first solutions
# 重写了下get_solution及存储的表结构
df_edges = model.get_solution(f"sol_lp_{pick_instance}/")
lpval = model.model.objval

# %%
df_edges

# %%
from tqdm.notebook import tqdm as tqdm_notebook

import utils
from cp_gfc import *

model.model.setParam("Logging", 0)
# get the first solutions
# 重写了下get_solution及存储的表结构
df_edges = model.get_solution(f"sol_lp_{pick_instance}/")
if df_edges.empty:
    print("no solution")
else:
    print('----------Originial Solution----------')
    for _, row in df_edges.iterrows():
        if 0 < row['y'] < 1:
            print(row["obj_start"], row["obj_end"], row["t"], row['y'])
    # print(df_edges['y'])
lpval = model.model.objval

# for t in range(arg.T):
# Out:
# [facinv] 2023-11-03 13:53:48,035: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:53:48,050: saving finished
# ----------Originial Solution----------
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 1 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0003 4 0.9999999999999996
# T0015 T0003 5 0.9999999999999996
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998

# %%
if not query_fractional_inter_edges(df_edges).empty:
    n = 1
    for _, row in query_fractional_inter_edges(df_edges).iterrows():
        start, end, t = row["obj_start"], row["obj_end"], row["t"]
        print("------------------Fractional Inter Edge------------------")
        print(k, start, end, t)
        k = 0
        while k < 20:
            # break
            for e in utils.get_out_edges(network, end):
                if e.capacity > 1e6:
                    print("无上界约束的边", e)
                    e.capacity = 0.4e5

            N1 = [e for e in utils.get_out_edges(network, end) if e.capacity < 1e6]
            N2 = [e for e in utils.get_in_edges(network, end) if e.capacity < 1e6]
            x = model.variables["sku_flow"]
            y = model.variables["select_edge"]
            d = 0
            print('---------Seperation Start----------')
            cutv, lbdv, subsets = seperation_gcf(model, x, y, t, N1, N2, d, dump=False, verbose=False)
            print("lbd", lbdv)
            if cutv > 1e-2:
                # 修改点2
                print('---------Add Cut----------')
                expr, cut_value, lbd, bool_voilate = eval_cut_c3(x, y, t, d, *subsets, lbdv=lbdv)
                model.model.addConstr(expr <= 0)
                model.model.solve()
                df_edges = model.get_solution(f"sol_lp_{pick_instance}/")
            else:
                print("cannot find")
                # print(df_edges['y'])
                for _, row in df_edges.iterrows():
                    if 0 < row['y'] < 1:
                        print(row["obj_start"], row["obj_end"], row["t"], row['y'])
                break
            # 看这一步和上一步相比的提升效果 新增了看这一步和mip之间的效果
            print(f"""
            --- {k} ---
            {start, end, t}
            {model.model.objval - lpval}
            {model.model.objval - mipval}
                """)
            lpval = model.model.objval
            k += 1
        print('After adding cuts for {}th fractional inter edge, then we have:'.format(n))
        for _, row in df_edges.iterrows():
            if 0 < row['y'] < 1:
                print(row["obj_start"], row["obj_end"], row["t"], row['y'])
        n += 1
else:
    print("no fractional inter edges")
    print(df_edges['y'])
# Out:
# ------------------Fractional Inter Edge------------------
# 6 T0015 T0003 4
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 22 rows, 103 columns and 64 nonzeros
# Model fingerprint: 0xa704c1a7
# Model has 60 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 57 general constraints
# Variable types: 67 continuous, 36 integer (36 binary)
# Coefficient statistics:
#   Matrix range     [1e-10, 4e+04]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e-10, 1e+00]
#   Objective range  [1e-10, 4e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-10, 1e+00]
#   QRHS range       [1e-10, 1e-10]
#   GenCon const rng [1e+01, 4e+04]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve added 91 rows and 30 columns
# Presolve time: 0.01s
# Presolved: 223 rows, 199 columns, 546 nonzeros
# Variable types: 133 continuous, 66 integer (66 binary)
# Found heuristic solution: objective 0.0000000
#
# Root relaxation: objective 3.513160e+06, 163 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3513160.26    0   54    0.00000 3513160.26      -     -    0s
# H    0     0                       0.0000000 3143920.88      -     -    0s
# H    0     0                       0.0000001 3005088.49      -     -    0s
#      0     0 3005088.49    0   53    0.00000 3005088.49      -     -    0s
#      0     0 2981624.51    0   53    0.00000 2981624.51      -     -    0s
#      0     0 2845415.86    0   52    0.00000 2845415.86      -     -    0s
#      0     0 2754281.08    0   49    0.00000 2754281.08      -     -    0s
# H    0     0                       0.0000001 2754281.08      -     -    0s
#      0     2 2754281.08    0   49    0.00000 2754281.08      -     -    0s
# H  120   144                       0.0029466 2344952.87      -  16.4    0s
# H 1840  1110                       0.0089805 1438866.62      -   7.2    0s
# H 1849  1056                       0.1323453 1438866.62      -   7.2    0s
# H 7372  2596                       0.3057695 888108.977      -   6.5    0s
# H 7373  2596                       0.3842624 888108.977      -   6.5    0s
# H 7407  2604                       0.4061423 888108.977      -   6.5    0s
# H21670  7856                       0.4186444 683231.403      -   5.8    0s
# H21677  7856                       0.4330596 683231.403      -   5.8    0s
# H29777  9969                       0.4704214 644806.963      -   5.6    1s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 20
#   Implied bound: 5
#   Clique: 1
#   MIR: 35
#   Flow cover: 166
#   RLT: 90
#   Relax-and-lift: 46
#
# Explored 75872 nodes (567551 simplex iterations) in 4.55 seconds (5.22 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 0.470421 0.00898051 0.00294659 ... 4.6035e-08
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective -0.000000000000e+00, best bound 4.704214090307e-01, gap -
# lbd 51195.17522165828
# cannot find
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 1 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0003 4 0.9999999999999996
# T0015 T0003 5 0.9999999999999996
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998
# After adding cuts for 1th fractional inter edge, then we have:
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 1 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0003 4 0.9999999999999996
# T0015 T0003 5 0.9999999999999996
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998
# ------------------Fractional Inter Edge------------------
# 0 T0015 T0014 0
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x5f66a0f6
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [5e-01, 5e-01]
#   QLMatrix range   [5e-01, 9e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 9e+02]
#   QRHS range       [9e+02, 9e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -40.2540323
# Found heuristic solution: objective -25.3446816
#
# Root relaxation: objective 6.963555e+05, 111 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696355.514    0   43  -25.34468 696355.514      -     -    0s
# H    0     0                       0.0000000 696355.514      -     -    0s
# H    0     0                       0.0120000 696355.514      -     -    0s
#      0     0 597977.513    0   38    0.01200 597977.513      -     -    0s
#      0     0 564493.942    0   39    0.01200 564493.942      -     -    0s
#      0     0 396930.830    0   30    0.01200 396930.830      -     -    0s
#      0     0 372561.143    0   31    0.01200 372561.143      -     -    0s
#      0     0 372561.143    0   32    0.01200 372561.143      -     -    0s
#      0     0 346433.676    0   45    0.01200 346433.676      -     -    0s
#      0     0 321572.618    0   45    0.01200 321572.618      -     -    0s
#      0     2 321572.618    0   45    0.01200 321572.618      -     -    0s
# H  126   130                       0.0332345 273928.968      -   5.9    0s
# H  135   130                       0.2371426 273928.968      -   5.8    0s
# H 2953  1380                       0.5841780 166137.958      -   5.5    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 11
#   Implied bound: 9
#   Projected implied bound: 2
#   Clique: 8
#   MIR: 31
#   Flow cover: 65
#   RLT: 66
#   Relax-and-lift: 18
#
# Explored 116988 nodes (566567 simplex iterations) in 2.58 seconds (2.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 0.584178 0.0332345 0.012 ... -40.254
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective -0.000000000000e+00, best bound 5.841779570546e-01, gap -
# lbd 20285.33903823654
# cannot find
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 1 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0003 4 0.9999999999999996
# T0015 T0003 5 0.9999999999999996
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998
# After adding cuts for 2th fractional inter edge, then we have:
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 1 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0003 4 0.9999999999999996
# T0015 T0003 5 0.9999999999999996
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998
# ------------------Fractional Inter Edge------------------
# 0 T0015 T0014 1
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0xa1113e35
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 3e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 3e+02]
#   QRHS range       [3e+02, 3e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.00s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -19.0711222
# Found heuristic solution: objective -12.0075305
# Found heuristic solution: objective -12.0075305
#
# Root relaxation: objective 6.960248e+05, 112 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696024.840    0   43  -12.00753 696024.840      -     -    0s
# H    0     0                       0.0000000 696024.840      -     -    0s
# H    0     0                       0.0130000 696024.840      -     -    0s
#      0     0 594800.467    0   37    0.01300 594800.467      -     -    0s
#      0     0 542619.972    0   37    0.01300 542619.972      -     -    0s
#      0     0 397313.605    0   29    0.01300 397313.605      -     -    0s
#      0     0 371502.972    0   31    0.01300 371502.972      -     -    0s
#      0     0 370722.971    0   30    0.01300 370722.971      -     -    0s
#      0     0 346433.676    0   46    0.01300 346433.676      -     -    0s
#      0     0 321174.831    0   41    0.01300 321174.831      -     -    0s
#      0     2 321174.831    0   40    0.01300 321174.831      -     -    0s
# *  210   163              19       0.0326730 271229.620      -   6.1    0s
# *  259   185              19       0.0326732 246361.336      -   6.2    0s
# H  277   211                       0.0332779 246361.336      -   6.5    0s
# H  302   211                       0.0336730 246361.336      -   6.4    0s
# H 1554   600                       0.3063060 195976.643      -   6.1    0s
# H 1957   714                       0.3084693 184415.396      -   6.2    0s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 11
#   Implied bound: 10
#   Projected implied bound: 2
#   Clique: 3
#   MIR: 51
#   StrongCG: 1
#   Flow cover: 64
#   Inf proof: 1
#   RLT: 79
#   Relax-and-lift: 19
#
# Explored 136312 nodes (967907 simplex iterations) in 3.79 seconds (3.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 0.308469 0.033673 0.0332779 ... -19.0711
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective -0.000000000000e+00, best bound 3.084693474739e-01, gap -
# lbd 41932.738477314
# cannot find
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 1 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0003 4 0.9999999999999996
# T0015 T0003 5 0.9999999999999996
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998
# After adding cuts for 3th fractional inter edge, then we have:
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 1 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0003 4 0.9999999999999996
# T0015 T0003 5 0.9999999999999996
# T0015 T0014 0 0.5092955028135911
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 4 0.02248106001312964
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998
# ------------------Fractional Inter Edge------------------
# 0 T0015 T0014 3
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x6afdf03b
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 2e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 2e+02]
#   QRHS range       [2e+02, 2e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -15.7845057
# Found heuristic solution: objective -9.9382161
# Found heuristic solution: objective -9.9382161
#
# Root relaxation: objective 6.960031e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696003.128    0   43   -9.93822 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0110000 696003.128      -     -    0s
#      0     0 583458.497    0   40    0.01100 583458.497      -     -    0s
#      0     0 523291.777    0   41    0.01100 523291.777      -     -    0s
#      0     0 372872.050    0   29    0.01100 372872.050      -     -    0s
#      0     0 367489.901    0   28    0.01100 367489.901      -     -    0s
#      0     0 363730.859    0   27    0.01100 363730.859      -     -    0s
#      0     0 344808.655    0   42    0.01100 344808.655      -     -    0s
#      0     0 325198.423    0   46    0.01100 325198.423      -     -    0s
#      0     0 323796.054    0   46    0.01100 323796.054      -     -    0s
#      0     0 295670.023    0   46    0.01100 295670.023      -     -    0s
#      0     0 291232.864    0   44    0.01100 291232.864      -     -    0s
#      0     2 291232.864    0   44    0.01100 291232.864      -     -    0s
# *  183   186              20       0.0326323 291232.864      -   8.2    0s
# *  189   186              20       0.0326732 291232.864      -   8.1    0s
# *  216   178              22       0.0326742 291232.864      -   7.8    0s
# H  266   170                       0.0336669 291232.864      -   7.2    0s
# H  275   170                       0.0336710 291232.864      -   7.7    0s
# H  279   170                       0.0363516 291232.864      -   8.0    0s
# H  287   170                       0.1171146 291232.864      -   7.8    0s
# H 1976  1068                       0.1184525 207454.156      -   7.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 4
#   MIR: 33
#   Flow cover: 74
#   Inf proof: 1
#   RLT: 64
#   Relax-and-lift: 10
#
# Explored 85034 nodes (668290 simplex iterations) in 3.10 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.118453 0.0363516 0.033671 ... -9.93822
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.302573433713e-02, best bound 1.184525242243e-01, gap 809.3731%
# lbd 17809.789935206103
# ---------Add Cut----------
# [facinv] 2023-11-03 13:54:05,231: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:54:05,245: saving finished
#
#             --- 0 ---
#             (T0015, T0014, 3)
#             0.0
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x6afdf03b
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 2e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 2e+02]
#   QRHS range       [2e+02, 2e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -15.7845057
# Found heuristic solution: objective -9.9382161
# Found heuristic solution: objective -9.9382161
#
# Root relaxation: objective 6.960031e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696003.128    0   43   -9.93822 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0110000 696003.128      -     -    0s
#      0     0 583458.497    0   40    0.01100 583458.497      -     -    0s
#      0     0 523291.777    0   41    0.01100 523291.777      -     -    0s
#      0     0 372872.050    0   29    0.01100 372872.050      -     -    0s
#      0     0 367489.901    0   28    0.01100 367489.901      -     -    0s
#      0     0 363730.859    0   27    0.01100 363730.859      -     -    0s
#      0     0 344808.655    0   42    0.01100 344808.655      -     -    0s
#      0     0 325198.423    0   46    0.01100 325198.423      -     -    0s
#      0     0 323796.054    0   46    0.01100 323796.054      -     -    0s
#      0     0 295670.023    0   46    0.01100 295670.023      -     -    0s
#      0     0 291232.864    0   44    0.01100 291232.864      -     -    0s
#      0     2 291232.864    0   44    0.01100 291232.864      -     -    0s
# *  183   186              20       0.0326323 291232.864      -   8.2    0s
# *  189   186              20       0.0326732 291232.864      -   8.1    0s
# *  216   178              22       0.0326742 291232.864      -   7.8    0s
# H  266   170                       0.0336669 291232.864      -   7.2    0s
# H  275   170                       0.0336710 291232.864      -   7.7    0s
# H  279   170                       0.0363516 291232.864      -   8.0    0s
# H  287   170                       0.1171146 291232.864      -   7.8    0s
# H 1976  1068                       0.1184525 207454.156      -   7.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 4
#   MIR: 33
#   Flow cover: 74
#   Inf proof: 1
#   RLT: 64
#   Relax-and-lift: 10
#
# Explored 85034 nodes (668290 simplex iterations) in 3.01 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.118453 0.0363516 0.033671 ... -9.93822
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.302573433713e-02, best bound 1.184525242243e-01, gap 809.3731%
# lbd 17809.789935206103
# ---------Add Cut----------
# [facinv] 2023-11-03 13:54:08,394: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:54:08,408: saving finished
#
#             --- 1 ---
#             (T0015, T0014, 3)
#             0.0
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x6afdf03b
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 2e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 2e+02]
#   QRHS range       [2e+02, 2e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.00s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -15.7845057
# Found heuristic solution: objective -9.9382161
# Found heuristic solution: objective -9.9382161
#
# Root relaxation: objective 6.960031e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696003.128    0   43   -9.93822 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0110000 696003.128      -     -    0s
#      0     0 583458.497    0   40    0.01100 583458.497      -     -    0s
#      0     0 523291.777    0   41    0.01100 523291.777      -     -    0s
#      0     0 372872.050    0   29    0.01100 372872.050      -     -    0s
#      0     0 367489.901    0   28    0.01100 367489.901      -     -    0s
#      0     0 363730.859    0   27    0.01100 363730.859      -     -    0s
#      0     0 344808.655    0   42    0.01100 344808.655      -     -    0s
#      0     0 325198.423    0   46    0.01100 325198.423      -     -    0s
#      0     0 323796.054    0   46    0.01100 323796.054      -     -    0s
#      0     0 295670.023    0   46    0.01100 295670.023      -     -    0s
#      0     0 291232.864    0   44    0.01100 291232.864      -     -    0s
#      0     2 291232.864    0   44    0.01100 291232.864      -     -    0s
# *  183   186              20       0.0326323 291232.864      -   8.2    0s
# *  189   186              20       0.0326732 291232.864      -   8.1    0s
# *  216   178              22       0.0326742 291232.864      -   7.8    0s
# H  266   170                       0.0336669 291232.864      -   7.2    0s
# H  275   170                       0.0336710 291232.864      -   7.7    0s
# H  279   170                       0.0363516 291232.864      -   8.0    0s
# H  287   170                       0.1171146 291232.864      -   7.8    0s
# H 1976  1068                       0.1184525 207454.156      -   7.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 4
#   MIR: 33
#   Flow cover: 74
#   Inf proof: 1
#   RLT: 64
#   Relax-and-lift: 10
#
# Explored 85034 nodes (668290 simplex iterations) in 3.12 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.118453 0.0363516 0.033671 ... -9.93822
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.302573433713e-02, best bound 1.184525242243e-01, gap 809.3731%
# lbd 17809.789935206103
# ---------Add Cut----------
# [facinv] 2023-11-03 13:54:11,672: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:54:11,686: saving finished
#
#             --- 2 ---
#             (T0015, T0014, 3)
#             0.0
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x6afdf03b
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 2e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 2e+02]
#   QRHS range       [2e+02, 2e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -15.7845057
# Found heuristic solution: objective -9.9382161
# Found heuristic solution: objective -9.9382161
#
# Root relaxation: objective 6.960031e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696003.128    0   43   -9.93822 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0110000 696003.128      -     -    0s
#      0     0 583458.497    0   40    0.01100 583458.497      -     -    0s
#      0     0 523291.777    0   41    0.01100 523291.777      -     -    0s
#      0     0 372872.050    0   29    0.01100 372872.050      -     -    0s
#      0     0 367489.901    0   28    0.01100 367489.901      -     -    0s
#      0     0 363730.859    0   27    0.01100 363730.859      -     -    0s
#      0     0 344808.655    0   42    0.01100 344808.655      -     -    0s
#      0     0 325198.423    0   46    0.01100 325198.423      -     -    0s
#      0     0 323796.054    0   46    0.01100 323796.054      -     -    0s
#      0     0 295670.023    0   46    0.01100 295670.023      -     -    0s
#      0     0 291232.864    0   44    0.01100 291232.864      -     -    0s
#      0     2 291232.864    0   44    0.01100 291232.864      -     -    0s
# *  183   186              20       0.0326323 291232.864      -   8.2    0s
# *  189   186              20       0.0326732 291232.864      -   8.1    0s
# *  216   178              22       0.0326742 291232.864      -   7.8    0s
# H  266   170                       0.0336669 291232.864      -   7.2    0s
# H  275   170                       0.0336710 291232.864      -   7.7    0s
# H  279   170                       0.0363516 291232.864      -   8.0    0s
# H  287   170                       0.1171146 291232.864      -   7.8    0s
# H 1976  1068                       0.1184525 207454.156      -   7.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 4
#   MIR: 33
#   Flow cover: 74
#   Inf proof: 1
#   RLT: 64
#   Relax-and-lift: 10
#
# Explored 85034 nodes (668290 simplex iterations) in 3.06 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.118453 0.0363516 0.033671 ... -9.93822
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.302573433713e-02, best bound 1.184525242243e-01, gap 809.3731%
# lbd 17809.789935206103
# ---------Add Cut----------
# [facinv] 2023-11-03 13:54:14,890: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:54:14,905: saving finished
#
#             --- 3 ---
#             (T0015, T0014, 3)
#             0.0
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x6afdf03b
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 2e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 2e+02]
#   QRHS range       [2e+02, 2e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -15.7845057
# Found heuristic solution: objective -9.9382161
# Found heuristic solution: objective -9.9382161
#
# Root relaxation: objective 6.960031e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696003.128    0   43   -9.93822 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0110000 696003.128      -     -    0s
#      0     0 583458.497    0   40    0.01100 583458.497      -     -    0s
#      0     0 523291.777    0   41    0.01100 523291.777      -     -    0s
#      0     0 372872.050    0   29    0.01100 372872.050      -     -    0s
#      0     0 367489.901    0   28    0.01100 367489.901      -     -    0s
#      0     0 363730.859    0   27    0.01100 363730.859      -     -    0s
#      0     0 344808.655    0   42    0.01100 344808.655      -     -    0s
#      0     0 325198.423    0   46    0.01100 325198.423      -     -    0s
#      0     0 323796.054    0   46    0.01100 323796.054      -     -    0s
#      0     0 295670.023    0   46    0.01100 295670.023      -     -    0s
#      0     0 291232.864    0   44    0.01100 291232.864      -     -    0s
#      0     2 291232.864    0   44    0.01100 291232.864      -     -    0s
# *  183   186              20       0.0326323 291232.864      -   8.2    0s
# *  189   186              20       0.0326732 291232.864      -   8.1    0s
# *  216   178              22       0.0326742 291232.864      -   7.8    0s
# H  266   170                       0.0336669 291232.864      -   7.2    0s
# H  275   170                       0.0336710 291232.864      -   7.7    0s
# H  279   170                       0.0363516 291232.864      -   8.0    0s
# H  287   170                       0.1171146 291232.864      -   7.8    0s
# H 1976  1068                       0.1184525 207454.156      -   7.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 4
#   MIR: 33
#   Flow cover: 74
#   Inf proof: 1
#   RLT: 64
#   Relax-and-lift: 10
#
# Explored 85034 nodes (668290 simplex iterations) in 3.12 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.118453 0.0363516 0.033671 ... -9.93822
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.302573433713e-02, best bound 1.184525242243e-01, gap 809.3731%
# lbd 17809.789935206103
# ---------Add Cut----------
# [facinv] 2023-11-03 13:54:18,171: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:54:18,185: saving finished
#
#             --- 4 ---
#             (T0015, T0014, 3)
#             0.0
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x6afdf03b
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 2e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 2e+02]
#   QRHS range       [2e+02, 2e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -15.7845057
# Found heuristic solution: objective -9.9382161
# Found heuristic solution: objective -9.9382161
#
# Root relaxation: objective 6.960031e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696003.128    0   43   -9.93822 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0110000 696003.128      -     -    0s
#      0     0 583458.497    0   40    0.01100 583458.497      -     -    0s
#      0     0 523291.777    0   41    0.01100 523291.777      -     -    0s
#      0     0 372872.050    0   29    0.01100 372872.050      -     -    0s
#      0     0 367489.901    0   28    0.01100 367489.901      -     -    0s
#      0     0 363730.859    0   27    0.01100 363730.859      -     -    0s
#      0     0 344808.655    0   42    0.01100 344808.655      -     -    0s
#      0     0 325198.423    0   46    0.01100 325198.423      -     -    0s
#      0     0 323796.054    0   46    0.01100 323796.054      -     -    0s
#      0     0 295670.023    0   46    0.01100 295670.023      -     -    0s
#      0     0 291232.864    0   44    0.01100 291232.864      -     -    0s
#      0     2 291232.864    0   44    0.01100 291232.864      -     -    0s
# *  183   186              20       0.0326323 291232.864      -   8.2    0s
# *  189   186              20       0.0326732 291232.864      -   8.1    0s
# *  216   178              22       0.0326742 291232.864      -   7.8    0s
# H  266   170                       0.0336669 291232.864      -   7.2    0s
# H  275   170                       0.0336710 291232.864      -   7.7    0s
# H  279   170                       0.0363516 291232.864      -   8.0    0s
# H  287   170                       0.1171146 291232.864      -   7.8    0s
# H 1976  1068                       0.1184525 207454.156      -   7.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 4
#   MIR: 33
#   Flow cover: 74
#   Inf proof: 1
#   RLT: 64
#   Relax-and-lift: 10
#
# Explored 85034 nodes (668290 simplex iterations) in 3.27 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.118453 0.0363516 0.033671 ... -9.93822
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.302573433713e-02, best bound 1.184525242243e-01, gap 809.3731%
# lbd 17809.789935206103
# ---------Add Cut----------
# [facinv] 2023-11-03 13:54:21,602: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:54:21,617: saving finished
#
#             --- 5 ---
#             (T0015, T0014, 3)
#             0.0
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x6afdf03b
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 2e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 2e+02]
#   QRHS range       [2e+02, 2e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -15.7845057
# Found heuristic solution: objective -9.9382161
# Found heuristic solution: objective -9.9382161
#
# Root relaxation: objective 6.960031e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696003.128    0   43   -9.93822 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0110000 696003.128      -     -    0s
#      0     0 583458.497    0   40    0.01100 583458.497      -     -    0s
#      0     0 523291.777    0   41    0.01100 523291.777      -     -    0s
#      0     0 372872.050    0   29    0.01100 372872.050      -     -    0s
#      0     0 367489.901    0   28    0.01100 367489.901      -     -    0s
#      0     0 363730.859    0   27    0.01100 363730.859      -     -    0s
#      0     0 344808.655    0   42    0.01100 344808.655      -     -    0s
#      0     0 325198.423    0   46    0.01100 325198.423      -     -    0s
#      0     0 323796.054    0   46    0.01100 323796.054      -     -    0s
#      0     0 295670.023    0   46    0.01100 295670.023      -     -    0s
#      0     0 291232.864    0   44    0.01100 291232.864      -     -    0s
#      0     2 291232.864    0   44    0.01100 291232.864      -     -    0s
# *  183   186              20       0.0326323 291232.864      -   8.2    0s
# *  189   186              20       0.0326732 291232.864      -   8.1    0s
# *  216   178              22       0.0326742 291232.864      -   7.8    0s
# H  266   170                       0.0336669 291232.864      -   7.2    0s
# H  275   170                       0.0336710 291232.864      -   7.7    0s
# H  279   170                       0.0363516 291232.864      -   8.0    0s
# H  287   170                       0.1171146 291232.864      -   7.8    0s
# H 1976  1068                       0.1184525 207454.156      -   7.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 4
#   MIR: 33
#   Flow cover: 74
#   Inf proof: 1
#   RLT: 64
#   Relax-and-lift: 10
#
# Explored 85034 nodes (668290 simplex iterations) in 3.17 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.118453 0.0363516 0.033671 ... -9.93822
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.302573433713e-02, best bound 1.184525242243e-01, gap 809.3731%
# lbd 17809.789935206103
# ---------Add Cut----------
# [facinv] 2023-11-03 13:54:24,933: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:54:24,945: saving finished
#
#             --- 6 ---
#             (T0015, T0014, 3)
#             0.0
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x6afdf03b
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 2e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 2e+02]
#   QRHS range       [2e+02, 2e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.00s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -15.7845057
# Found heuristic solution: objective -9.9382161
# Found heuristic solution: objective -9.9382161
#
# Root relaxation: objective 6.960031e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696003.128    0   43   -9.93822 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0110000 696003.128      -     -    0s
#      0     0 583458.497    0   40    0.01100 583458.497      -     -    0s
#      0     0 523291.777    0   41    0.01100 523291.777      -     -    0s
#      0     0 372872.050    0   29    0.01100 372872.050      -     -    0s
#      0     0 367489.901    0   28    0.01100 367489.901      -     -    0s
#      0     0 363730.859    0   27    0.01100 363730.859      -     -    0s
#      0     0 344808.655    0   42    0.01100 344808.655      -     -    0s
#      0     0 325198.423    0   46    0.01100 325198.423      -     -    0s
#      0     0 323796.054    0   46    0.01100 323796.054      -     -    0s
#      0     0 295670.023    0   46    0.01100 295670.023      -     -    0s
#      0     0 291232.864    0   44    0.01100 291232.864      -     -    0s
#      0     2 291232.864    0   44    0.01100 291232.864      -     -    0s
# *  183   186              20       0.0326323 291232.864      -   8.2    0s
# *  189   186              20       0.0326732 291232.864      -   8.1    0s
# *  216   178              22       0.0326742 291232.864      -   7.8    0s
# H  266   170                       0.0336669 291232.864      -   7.2    0s
# H  275   170                       0.0336710 291232.864      -   7.7    0s
# H  279   170                       0.0363516 291232.864      -   8.0    0s
# H  287   170                       0.1171146 291232.864      -   7.8    0s
# H 1976  1068                       0.1184525 207454.156      -   7.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 4
#   MIR: 33
#   Flow cover: 74
#   Inf proof: 1
#   RLT: 64
#   Relax-and-lift: 10
#
# Explored 85034 nodes (668290 simplex iterations) in 3.12 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.118453 0.0363516 0.033671 ... -9.93822
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.302573433713e-02, best bound 1.184525242243e-01, gap 809.3731%
# lbd 17809.789935206103
# ---------Add Cut----------
# [facinv] 2023-11-03 13:54:28,212: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:54:28,225: saving finished
#
#             --- 7 ---
#             (T0015, T0014, 3)
#             0.0
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0x6afdf03b
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [2e-01, 2e-01]
#   QLMatrix range   [2e-01, 2e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 2e+02]
#   QRHS range       [2e+02, 2e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -15.7845057
# Found heuristic solution: objective -9.9382161
# Found heuristic solution: objective -9.9382161
#
# Root relaxation: objective 6.960031e+05, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696003.128    0   43   -9.93822 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0000000 696003.128      -     -    0s
# H    0     0                       0.0110000 696003.128      -     -    0s
#      0     0 583458.497    0   40    0.01100 583458.497      -     -    0s
#      0     0 523291.777    0   41    0.01100 523291.777      -     -    0s
#      0     0 372872.050    0   29    0.01100 372872.050      -     -    0s
#      0     0 367489.901    0   28    0.01100 367489.901      -     -    0s
#      0     0 363730.859    0   27    0.01100 363730.859      -     -    0s
#      0     0 344808.655    0   42    0.01100 344808.655      -     -    0s
#      0     0 325198.423    0   46    0.01100 325198.423      -     -    0s
#      0     0 323796.054    0   46    0.01100 323796.054      -     -    0s
#      0     0 295670.023    0   46    0.01100 295670.023      -     -    0s
#      0     0 291232.864    0   44    0.01100 291232.864      -     -    0s
#      0     2 291232.864    0   44    0.01100 291232.864      -     -    0s
# *  183   186              20       0.0326323 291232.864      -   8.2    0s
# *  189   186              20       0.0326732 291232.864      -   8.1    0s
# *  216   178              22       0.0326742 291232.864      -   7.8    0s
# H  266   170                       0.0336669 291232.864      -   7.2    0s
# H  275   170                       0.0336710 291232.864      -   7.7    0s
# H  279   170                       0.0363516 291232.864      -   8.0    0s
# H  287   170                       0.1171146 291232.864      -   7.8    0s
# H 1976  1068                       0.1184525 207454.156      -   7.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   Implied bound: 13
#   Projected implied bound: 1
#   Clique: 4
#   MIR: 33
#   Flow cover: 74
#   Inf proof: 1
#   RLT: 64
#   Relax-and-lift: 10
#
# Explored 85034 nodes (668290 simplex iterations) in 3.71 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.118453 0.0363516 0.033671 ... -9.93822
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.302573433713e-02, best bound 1.184525242243e-01, gap 809.3731%
# lbd 17809.789935206103
# ---------Add Cut----------
# [facinv] 2023-11-03 13:54:32,082: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:54:32,099: saving finished
#
#             --- 8 ---
#             (T0015, T0014, 3)
#             0.0
#             -269.9243535856949
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# ...
#      0     0 372872.050    0   40    0.00000 372872.050      -     -    0s
#      0     0 325198.423    0   41    0.00000 325198.423      -     -    0s
#      0     0 311839.751    0   38    0.00000 311839.751      -     -    0s
#      0     2 311839.751    0   38    0.00000 311839.751      -     -    0s
# H  195   170                       0.0156406 303237.991      -   7.2    0s
# H  284   211                       0.0180930 278289.188      -   6.7    0s
# H 1740   925                       0.0290671 177863.990      -   6.1    0s
# H 2953  1126                       0.0302139 153651.979      -   5.5    0s
# *36527  2037              42       0.5047172 6308.72088      -   5.3    1s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 11
#   Implied bound: 7
#   Projected implied bound: 1
#   Clique: 6
#   MIR: 15
#   Flow cover: 42
#   RLT: 64
#   Relax-and-lift: 12
#
# Explored 57937 nodes (325850 simplex iterations) in 1.62 seconds (1.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0.504717 0.0302139 1.40717e-08 6.39103e-09
# No other solutions better than 0.504717
#
# Optimal solution found (tolerance 1.00e-02)
# Warning: max constraint violation (5.0472e-01) exceeds tolerance
# Warning: max general constraint violation (5.0472e-01) exceeds tolerance
#          (model may be infeasible or unbounded - try turning presolve off)
# Best objective 5.047171700018e-01, best bound 5.047171699958e-01, gap 0.0000%
# lbd 16.21990147
# ---------Add Cut----------
# [facinv] 2023-11-03 13:55:50,083: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:55:50,103: saving finished
#
#             --- 17 ---
#             (T0015, T0014, 5)
#             0.0
#             -268.2920876359567
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 52 nonzeros
# Model fingerprint: 0x0a5ecf94
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 1e+00]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 26 columns
# Presolve time: 0.01s
# Presolved: 193 rows, 169 columns, 477 nonzeros
# Variable types: 114 continuous, 55 integer (55 binary)
# Found heuristic solution: objective 0.0000000
#
# Root relaxation: objective 6.959350e+05, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 695934.961    0   41    0.00000 695934.961      -     -    0s
# H    0     0                       0.0000000 695934.961      -     -    0s
#      0     0 450387.334    0   37    0.00000 450387.334      -     -    0s
# H    0     0                       0.0000000 450387.334      -     -    0s
#      0     0 450387.333    0   36    0.00000 450387.333      -     -    0s
#      0     0 393267.760    0   44    0.00000 393267.760      -     -    0s
#      0     0 372872.050    0   40    0.00000 372872.050      -     -    0s
#      0     0 325198.423    0   41    0.00000 325198.423      -     -    0s
#      0     0 311839.751    0   38    0.00000 311839.751      -     -    0s
#      0     2 311839.751    0   38    0.00000 311839.751      -     -    0s
# H  195   170                       0.0156406 303237.991      -   7.2    0s
# H  284   211                       0.0180930 278289.188      -   6.7    0s
# H 1740   925                       0.0290671 177863.990      -   6.1    0s
# H 2953  1126                       0.0302139 153651.979      -   5.5    0s
# *36527  2037              42       0.5047172 6308.72088      -   5.3    1s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 11
#   Implied bound: 7
#   Projected implied bound: 1
#   Clique: 6
#   MIR: 15
#   Flow cover: 42
#   RLT: 64
#   Relax-and-lift: 12
#
# Explored 57937 nodes (325850 simplex iterations) in 1.96 seconds (1.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0.504717 0.0302139 1.40717e-08 6.39103e-09
# No other solutions better than 0.504717
#
# Optimal solution found (tolerance 1.00e-02)
# Warning: max constraint violation (5.0472e-01) exceeds tolerance
# Warning: max general constraint violation (5.0472e-01) exceeds tolerance
#          (model may be infeasible or unbounded - try turning presolve off)
# Best objective 5.047171700018e-01, best bound 5.047171699958e-01, gap 0.0000%
# lbd 16.21990147
# ---------Add Cut----------
# [facinv] 2023-11-03 13:55:52,211: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:55:52,225: saving finished
#
#             --- 18 ---
#             (T0015, T0014, 5)
#             0.0
#             -268.2920876359567
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 52 nonzeros
# Model fingerprint: 0x0a5ecf94
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 1e+00]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 26 columns
# Presolve time: 0.01s
# Presolved: 193 rows, 169 columns, 477 nonzeros
# Variable types: 114 continuous, 55 integer (55 binary)
# Found heuristic solution: objective 0.0000000
#
# Root relaxation: objective 6.959350e+05, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 695934.961    0   41    0.00000 695934.961      -     -    0s
# H    0     0                       0.0000000 695934.961      -     -    0s
#      0     0 450387.334    0   37    0.00000 450387.334      -     -    0s
# H    0     0                       0.0000000 450387.334      -     -    0s
#      0     0 450387.333    0   36    0.00000 450387.333      -     -    0s
#      0     0 393267.760    0   44    0.00000 393267.760      -     -    0s
#      0     0 372872.050    0   40    0.00000 372872.050      -     -    0s
#      0     0 325198.423    0   41    0.00000 325198.423      -     -    0s
#      0     0 311839.751    0   38    0.00000 311839.751      -     -    0s
#      0     2 311839.751    0   38    0.00000 311839.751      -     -    0s
# H  195   170                       0.0156406 303237.991      -   7.2    0s
# H  284   211                       0.0180930 278289.188      -   6.7    0s
# H 1740   925                       0.0290671 177863.990      -   6.1    0s
# H 2953  1126                       0.0302139 153651.979      -   5.5    0s
# *36527  2037              42       0.5047172 6308.72088      -   5.3    1s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 11
#   Implied bound: 7
#   Projected implied bound: 1
#   Clique: 6
#   MIR: 15
#   Flow cover: 42
#   RLT: 64
#   Relax-and-lift: 12
#
# Explored 57937 nodes (325850 simplex iterations) in 1.75 seconds (1.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0.504717 0.0302139 1.40717e-08 6.39103e-09
# No other solutions better than 0.504717
#
# Optimal solution found (tolerance 1.00e-02)
# Warning: max constraint violation (5.0472e-01) exceeds tolerance
# Warning: max general constraint violation (5.0472e-01) exceeds tolerance
#          (model may be infeasible or unbounded - try turning presolve off)
# Best objective 5.047171700018e-01, best bound 5.047171699958e-01, gap 0.0000%
# lbd 16.21990147
# ---------Add Cut----------
# [facinv] 2023-11-03 13:55:54,119: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:55:54,132: saving finished
#
#             --- 19 ---
#             (T0015, T0014, 5)
#             0.0
#             -268.2920876359567
#
# After adding cuts for 6th fractional inter edge, then we have:
# T0015 T0014 0 0.6888049352211084
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999977
# ------------------Fractional Inter Edge------------------
# 20 T0015 T0014 6
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 56 nonzeros
# Model fingerprint: 0x79cdef73
# Model has 46 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e-10, 9e+04]
#   QMatrix range    [6e-01, 1e+00]
#   QLMatrix range   [1e-10, 7e+02]
#   Objective range  [1e-10, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-10, 7e+02]
#   QRHS range       [1e-10, 7e+02]
#   GenCon const rng [2e+01, 9e+04]
# Warning: Model contains large matrix coefficient range
# Warning: Quadratic constraints contain large coefficient range on linear part
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve added 86 rows and 38 columns
# Presolve time: 0.01s
# Presolved: 210 rows, 182 columns, 523 nonzeros
# Variable types: 123 continuous, 59 integer (59 binary)
# Found heuristic solution: objective 2.7621366
# Found heuristic solution: objective 3.0762676
#
# Root relaxation: objective 6.634392e+05, 112 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 663439.165    0   43    3.07627 663439.165      -     -    0s
# H    0     0                      12.8572432 663439.165      -     -    0s
#      0     0 563613.279    0   40   12.85724 563613.279      -     -    0s
#      0     0 533769.325    0   40   12.85724 533769.325      -     -    0s
#      0     0 372037.126    0   29   12.85724 372037.126      -     -    0s
#      0     0 349817.512    0   28   12.85724 349817.512      -     -    0s
#      0     0 349414.596    0   31   12.85724 349414.596      -     -    0s
#      0     0 349414.596    0   32   12.85724 349414.596      -     -    0s
#      0     0 320370.613    0   48   12.85724 320370.613      -     -    0s
#      0     0 298374.177    0   44   12.85724 298374.177      -     -    0s
#      0     2 298374.177    0   44   12.85724 298374.177      -     -    0s
# *  169   157              22      12.8582432 279328.366      -   5.8    0s
# H 1320   719                      12.8602432 204060.686      -   5.6    0s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 2
#   Implied bound: 5
#   Clique: 3
#   MIR: 19
#   Flow cover: 56
#   GUB cover: 1
#   RLT: 36
#   Relax-and-lift: 20
#
# Explored 30395 nodes (235762 simplex iterations) in 2.31 seconds (1.88 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 12.8602 12.8582 12.8572 ... 2.76214
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.285724319875e+01, best bound 1.286024319747e+01, gap 0.0233%
# lbd 34.0490125
# ---------Add Cut----------
# [facinv] 2023-11-03 13:55:56,586: table warehouse_total_avg_inventory failed
# [facinv] 2023-11-03 13:55:56,599: saving finished
#
#             --- 0 ---
#             (T0015, T0014, 6)
#             -1.6322659543948248
#             -269.92435359035153
#
# ---------Seperation Start----------
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 19 rows, 88 columns and 54 nonzeros
# Model fingerprint: 0xbc9c5c54
# Model has 47 quadratic objective terms
# Model has 6 quadratic constraints
# Model has 48 general constraints
# Variable types: 58 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+04]
#   QMatrix range    [6e-01, 6e-01]
#   QLMatrix range   [6e-01, 7e+02]
#   Objective range  [1e+00, 9e+04]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e+00, 7e+02]
#   QRHS range       [7e+02, 7e+02]
#   GenCon const rng [2e+01, 9e+04]
# Presolve added 76 rows and 23 columns
# Presolve time: 0.01s
# Presolved: 173 rows, 160 columns, 422 nonzeros
# Variable types: 106 continuous, 54 integer (54 binary)
# Found heuristic solution: objective -49.1928797
# Found heuristic solution: objective -30.9727449
#
# Root relaxation: objective 6.962272e+05, 111 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 696227.228    0   43  -30.97274 696227.228      -     -    0s
# H    0     0                       0.0000000 696227.228      -     -    0s
# H    0     0                       0.0060000 696227.228      -     -    0s
#      0     0 596764.133    0   37    0.00600 596764.133      -     -    0s
#      0     0 563200.857    0   38    0.00600 563200.857      -     -    0s
#      0     0 396975.759    0   30    0.00600 396975.759      -     -    0s
#      0     0 371731.464    0   32    0.00600 371731.464      -     -    0s
#      0     0 371502.972    0   32    0.00600 371502.972      -     -    0s
#      0     0 345273.607    0   48    0.00600 345273.607      -     -    0s
#      0     0 322081.158    0   48    0.00600 322081.158      -     -    0s
#      0     2 322081.158    0   48    0.00600 322081.158      -     -    0s
# *  139   131              19       0.0327257 285391.882      -   6.3    0s
# H  175   168                       0.0631100 285391.882      -   5.7    0s
# *29121  7609              39       0.3166495 13756.6130      -   5.6    1s
# *29168  7226              43       0.3874224 13756.6130      -   5.7    1s
# *29174  6859              43       0.4032348 13756.6130      -   5.7    1s
# *29207  6501              47       0.4141472 5051.12937      -   5.7    1s
# *29276  6146              47       0.4142544 1764.31227      -   5.7    1s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Implied bound: 6
#   Projected implied bound: 1
#   Clique: 8
#   MIR: 12
#   Flow cover: 35
#   RLT: 31
#   Relax-and-lift: 9
#
# Explored 29427 nodes (167107 simplex iterations) in 1.84 seconds (1.45 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.414254 0.414147 0.403235 ... -30.9727
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective -0.000000000000e+00, best bound 4.142543539674e-01, gap -
# lbd 3341.433418413997
# cannot find
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0014 0 0.8572725070234547
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999979
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998
# After adding cuts for 7th fractional inter edge, then we have:
# T0015 T0003 0 0.9999999999999996
# T0015 T0003 3 0.9999999999999996
# T0015 T0014 0 0.8572725070234547
# T0015 T0014 1 0.24128854237327274
# T0015 T0014 3 0.19970614903454542
# T0015 T0014 6 0.6223901295596365
# T0015 T0024 4 0.9999999999999979
# T0025 C00120540 0 0.9999999999999998
# T0025 C00120540 3 0.9999999999999998

# %%
# k = 0
# while k < 20:
#     for _, row in query_fractional_inter_edges(df_edges).iterrows():
#         start, end, t = row["obj_start"], row["obj_end"], row["t"]
#         break
#     # # 修改点1
#     for e in utils.get_out_edges(network, end):
#         if e.capacity > 1e6:
#             print(e)
#             # e.capacity = 0.9e6
#             e.capacity = 0.4e5
#
#     N1 = [e for e in utils.get_out_edges(network, end) if e.capacity < 1e6]
#     N2 = [e for e in utils.get_in_edges(network, end) if e.capacity < 1e6]
#     # 这样修改的话会导致seperation_gcf那里需要用capacity乘的地方有问题
#     # N1 = [e for e in utils.get_out_edges(network, end)]
#     # N2 = [e for e in utils.get_in_edges(network, end)]
#     x = model.variables["sku_flow"]
#     y = model.variables["select_edge"]
#     d = 0
#     t = 0
#     cutv, lbdv, subsets = seperation_gcf(model, x, y, t, N1, N2, d, dump=False, verbose=False)
#     print("lbd",lbdv)
#     # 1e-13 能有个0.852713
#     if cutv > 1e-13:
#         # 修改点2
#         expr, cut_value, lbd, bool_voilate = eval_cut_c3(x, y, t, d, *subsets, lbdv=lbdv)
#         model.model.addConstr(expr <= 0)
#         model.model.solve()
#         df_edges = model.get_solution(f"sol_lp_{pick_instance}/")
#         print(df_edges)
#     else:
#         print("cannot find", cutv)
#         break
#     # 看这一步和上一步相比的提升效果 新增了看这一步和mip之间的效果
#     print(f"""
# --- {k} ---
# {start, end, t}
# {model.model.objval - lpval}
# {model.model.objval - mipval}
#     """)
#     lpval = model.model.objval
#     # print(df_edges)
#     k += 1

# %%
subsets

# %%
df_edges

# %%
# %tb
